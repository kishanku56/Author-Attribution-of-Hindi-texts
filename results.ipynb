# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np    



#plt.plot([x for x in range(3,15)],random_forest_scores)

bow = pd.read_csv("bag of words/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")



algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Bag of words', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1793         try:
# -> 1794             return self.obj._take(key, axis=axis, convert=False)
#    1795         except IndexError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _take(self, indices, axis, convert, is_copy)
#    2149                                    axis=self._get_block_manager_axis(axis),
# -> 2150                                    verify=True)
#    2151         result = self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    4254         if convert:
# -> 4255             indexer = maybe_convert_indices(indexer, n)
#    4256
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in maybe_convert_indices(indices, n)
#    2102     if mask.any():
# -> 2103         raise IndexError("indices are out-of-bounds")
#    2104     return indices
#
# IndexError: indices are out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-886231c1c3f5> in <module>()
#      13 for x in range(5):
#      14     index=[5*i+x for i in range(20)]
# ---> 15     temp=bow.iloc[index]
#      16     print(temp.iloc[index[0]][0])
#      17     temp.iloc[index[0]][0]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1817         # a list of integers
#    1818         elif is_list_like_indexer(key):
# -> 1819             return self._get_list_axis(key, axis=axis)
#    1820
#    1821         # a single integer
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1795         except IndexError:
#    1796             # re-raise with different error message
# -> 1797             raise IndexError("positional indexers are out-of-bounds")
#    1798
#    1799     def _getitem_axis(self, key, axis=None):
#
# IndexError: positional indexers are out-of-bounds

# %%
bow = pd.read_csv("bigrams/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")



algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Bigrams', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("trigrams/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")



algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Trigrams', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("bi_trigrams/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")



algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Bigrams and trigrams', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("function_words/results for 10 authors")

algo_name=[]
algo_scores=[]

for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")




algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Function words', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("function_words_and_trigrams/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")



algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Function words and trigrams', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("pos_tagging/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")


algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('POS tagging', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("secondary_features/results for 5 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")


algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Secondary features', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()

# %%
bow = pd.read_csv("trigrams_and_secondary_features/results for 10 authors")

algo_name=[]
algo_scores=[]
for x in range(5):
    index=[5*i+x for i in range(20)]
    temp=bow.iloc[index]
    print(temp.iloc[index[0]][0])
    temp.iloc[index[0]][0]
    algo_name+=[temp.iloc[index[0]][0]]
    
    print(str(round(temp.mean()[0]*100,2))+" +- "+str(round(temp.std()[0]*100,2)))
    algo_scores+=[temp.mean()[0]*100-round(temp.std()[0]*100,2)]
    print(temp.std()[0]*100)
    
    print("\n")


algo_scores=np.array(algo_scores)
max_index=np.argmax(algo_scores)

plt.figure(figsize=(5,3))
plt.suptitle('Secondary features', fontsize=20)
graph=plt.bar(algo_name,algo_scores,align='center',label='bag_of_words')
graph[max_index].set_color('r')
plt.xticks(rotation='vertical')
plt.show()
