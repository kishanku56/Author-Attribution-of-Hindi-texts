# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import os
from sklearn import svm, model_selection, tree, preprocessing, metrics
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import codecs
from nltk.probability import FreqDist
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
import time

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
import nltk

from nltk.corpus import indian
from nltk.tag import tnt

train_data = indian.tagged_sents('hindi.pos')
tnt_pos_tagger = tnt.TnT()
tnt_pos_tagger.train(train_data) #Training the tnt Part of speech tagger with hindi data

# %%
path='Hindi_train/'
authors=os.listdir(path)
authors=authors[:5]
files=[]

# getting the list of files
for author in authors:
    newpath=path+author+'/'
    x=os.listdir(newpath)
    for every_file in x:
        full_path=newpath+every_file
        files=files+[full_path]

# %%
#reading documents from file paths
tagged_document=[]
length=[]

for file in files:
    tagged_words=[]
    tags=[]
    doc = codecs.open(file, "r", encoding='utf-16')
    doc = doc.read()
    words=nltk.word_tokenize(doc)
    for each in words:
        tagged_word=tnt_pos_tagger.tag([each])
        tagged_words+=[tagged_word[0][1]]
    tagged_document+=[tagged_words]
    length=length+[len(doc)]
tagged_document
# Out:
# [['Unk',
#   'PRP',
#   'PREP',
#   'INTF',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'PRP',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'JJ',
#   'PREP',
#   'JJ',
#   'NN',
#   'PREP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'RP',
#   'Unk',
#   'NN',
#   'RP',
#   'JVB',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'CC',
#   'Unk',
#   'PRP',
#   'PREP',
#   'QF',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'CC',
#   'NN',
#   'INTF',
#   'PREP',
#   'NN',
#   'PRP',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'INTF',
#   'RP',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NN',
#   'RP',
#   'NEG',
#   'VFM',
#   'SYM',
#   'PRP',
#   'NN',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NN',
#   'Unk',
#   'VAUX',
#   'CC',
#   'JVB',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'QW',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'JJ',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'CC',
#   'PRP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'RP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PRP',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'INTF',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VJJ',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PRP',
#   'RB',
#   'PREP',
#   'NN',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'RB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'QF',
#   'Unk',
#   'PREP',
#   'QF',
#   'NEG',
#   'QF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'INTF',
#   'Unk',
#   'Unk',
#   'RP',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'RB',
#   'INTF',
#   'PREP',
#   'NN',
#   'VFM',
#   'PRP',
#   'QF',
#   'NN',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'NEG',
#   'QF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'CC',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'PRP',
#   'PREP',
#   'INTF',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'NN',
#   'RB',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'QF',
#   'NN',
#   'Unk',
#   'NN',
#   'QF',
#   'PRP',
#   'NN',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VJJ',
#   'PUNC',
#   'PRP',
#   'NEG',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'RP',
#   'NEG',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'QFNUM',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'QFNUM',
#   'NN',
#   'Unk',
#   'NVB',
#   'VFM',
#   'PREP',
#   'RB',
#   'RP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'RB',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'INTF',
#   'Unk',
#   'NN',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'PRP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'NN',
#   'PREP',
#   'PREP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'CC',
#   'NN',
#   'Unk',
#   'VFM',
#   'VNN',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NN',
#   'VNN',
#   'Unk',
#   'VAUX',
#   'CC',
#   'INTF',
#   'RP',
#   'Unk',
#   'NVB',
#   'VJJ',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'INTF',
#   'JJ',
#   'NN',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PRP',
#   'QW',
#   'NN',
#   'PREP',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'PRP',
#   'NEG',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'QF',
#   'Unk',
#   'PREP',
#   'PREP',
#   'QW',
#   'RP',
#   'NN',
#   'PREP',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NEG',
#   'Unk',
#   'SYM',
#   'RB',
#   'PRP',
#   'RB',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'QW',
#   'PREP',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'NN',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'NEG',
#   'Unk',
#   'SYM',
#   'NN',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'QF',
#   'NN',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'RB',
#   'PREP',
#   'NN',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'VFM',
#   'Unk',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'PREP',
#   'PRP',
#   'NN',
#   'NN',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'NN',
#   'VFM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NVB',
#   'NVB',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'SYM',
#   'PRP',
#   'RP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'NLOC',
#   'Unk',
#   'PREP',
#   'PREP',
#   'NN',
#   'NN',
#   'NVB',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'CC',
#   'PRP',
#   'JJ',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'RP',
#   'Unk',
#   'PREP',
#   'NLOC',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'QW',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'NEG',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'JVB',
#   'VFM',
#   'RP',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RB',
#   'QF',
#   'NN',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PRP',
#   'NEG',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'INTF',
#   'NN',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'QW',
#   'PREP',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'JJ',
#   'Unk',
#   'RP',
#   'Unk',
#   'INTF',
#   'JJ',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'CC',
#   'NN',
#   'PREP',
#   'NLOC',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'QF',
#   'NN',
#   'PRP',
#   'Unk',
#   'Unk',
#   'QF',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'VFM',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'CC',
#   'PRP',
#   'JJ',
#   'NEG',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'INTF',
#   'JJ',
#   'Unk',
#   'NEG',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'QF',
#   'QW',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'VNN',
#   'VFM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'NN',
#   'PREP',
#   'PRP',
#   'RP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'NEG',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VJJ',
#   'VFM',
#   'RP',
#   'QFNUM',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'QF',
#   'PREP',
#   'Unk',
#   'CC',
#   'Unk',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'RB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'CC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'NVB',
#   'JJ',
#   'RP',
#   'VFM',
#   'SYM',
#   'RP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'QW',
#   'PREP',
#   'PRP',
#   'Unk',
#   'JVB',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'INTF',
#   'JJ',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'RP',
#   'PRP',
#   ...],
#  ['Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'CC',
#   'QW',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NN',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'RB',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'NEG',
#   'VFM',
#   'SYM',
#   'Unk',
#   'NN',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'PREP',
#   'CC',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QF',
#   'RP',
#   'NEG',
#   'SYM',
#   'QF',
#   'NN',
#   'Unk',
#   'NLOC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'NN',
#   'Unk',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'NLOC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NVB',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'QF',
#   'NN',
#   'Unk',
#   'PREP',
#   'NVB',
#   'PREP',
#   'PREP',
#   'VNN',
#   'PREP',
#   'QF',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'RB',
#   'CC',
#   'QW',
#   'RP',
#   'Unk',
#   'PREP',
#   'QW',
#   'JJ',
#   'NN',
#   'PREP',
#   'VJJ',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'PREP',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RP',
#   'NN',
#   'PRP',
#   'NN',
#   'PREP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'QF',
#   'Unk',
#   'CC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'JJ',
#   'Unk',
#   'PUNC',
#   'CC',
#   'PRP',
#   'Unk',
#   'QF',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'JVB',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'QF',
#   'NN',
#   'NN',
#   'Unk',
#   'PREP',
#   'PREP',
#   'NNP',
#   'PREP',
#   'NNC',
#   'VFM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'RP',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'RB',
#   'Unk',
#   'RP',
#   'QF',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'JJ',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'NN',
#   'PREP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'JVB',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'QW',
#   'NN',
#   'PREP',
#   'Unk',
#   'JJ',
#   'CC',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'NN',
#   'Unk',
#   'VFM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'CC',
#   'Unk',
#   'PREP',
#   'JJ',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NN',
#   'Unk',
#   'SYM',
#   'Unk',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'QF',
#   'PRP',
#   'NN',
#   'Unk',
#   'VFM',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'PREP',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NVB',
#   'VFM',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'VJJ',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'SYM',
#   'RB',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'PREP',
#   'Unk',
#   'QF',
#   'Unk',
#   'VNN',
#   'PREP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'INTF',
#   'JJ',
#   'Unk',
#   'NN',
#   'CC',
#   'NNC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NN',
#   'RP',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'INTF',
#   'Unk',
#   '',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'NN',
#   'PREP',
#   'VFM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'VFM',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'RB',
#   'Unk',
#   'VFM',
#   'VFM',
#   'PUNC',
#   'QW',
#   'NN',
#   'PREP',
#   'NN',
#   'PREP',
#   'INTF',
#   'JJ',
#   'Unk',
#   'VFM',
#   'PUNC',
#   'QW',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VFM',
#   'CC',
#   'QW',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'RB',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'RP',
#   'PRP',
#   'NN',
#   'Unk',
#   'PRP',
#   'JJ',
#   'JVB',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PRP',
#   'NVB',
#   'VFM',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'QF',
#   'NN',
#   'PRP',
#   'RB',
#   'RB',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'CC',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'QW',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'Unk',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'QF',
#   'NN',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'NLOC',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'INTF',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'RB',
#   'PRP',
#   'Unk',
#   'NEG',
#   'PREP',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'PREP',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'NN',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'RP',
#   'Unk',
#   'RP',
#   'VFM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RB',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'NN',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'INTF',
#   'JJ',
#   'Unk',
#   'PRP',
#   'RB',
#   'VJJ',
#   'VAUX',
#   'RB',
#   'PRP',
#   'PRP',
#   'RP',
#   'NN',
#   'RB',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'NEG',
#   'VJJ',
#   'CC',
#   'Unk',
#   'PRP',
#   'NN',
#   'NEG',
#   'VFM',
#   'CC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VFM',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'NN',
#   'RP',
#   'NEG',
#   'VJJ',
#   'PRP',
#   'PRP',
#   'PREP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'RB',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'CC',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NEG',
#   'Unk',
#   'SYM',
#   'CC',
#   'NN',
#   'VFM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QW',
#   'Unk',
#   'PREP',
#   'CC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QF',
#   'NN',
#   'Unk',
#   'PREP',
#   'QF',
#   'JJ',
#   'VNN',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'PRP',
#   'QF',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'CC',
#   'Unk',
#   'PREP',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'SYM',
#   'PRP',
#   'RP',
#   'NN',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'PRP',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RB',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'QF',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'CC',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'PRP',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'NN',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'PREP',
#   'RB',
#   'PRP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'RP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'RB',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QF',
#   'PRP',
#   'NN',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NNC',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'INTF',
#   'JJ',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NN',
#   'VJJ',
#   'VAUX',
#   'RP',
#   'NLOC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'QW',
#   'Unk',
#   ...],
#  ['NNP',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'INTF',
#   'JJ',
#   'PREP',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NNC',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VFM',
#   'SYM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'Unk',
#   'CC',
#   'RB',
#   'JVB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'RP',
#   'VFM',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'NN',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'CC',
#   'RB',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'NN',
#   'Unk',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PREP',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'SYM',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'PRP',
#   'QF',
#   'PRP',
#   'Unk',
#   'RP',
#   'Unk',
#   'SYM',
#   'JVB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'CC',
#   'Unk',
#   'VFM',
#   'SYM',
#   'RB',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'JVB',
#   'VFM',
#   'SYM',
#   'RP',
#   'Unk',
#   'NN',
#   'RP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'VNN',
#   'VFM',
#   'PRP',
#   'Unk',
#   'QF',
#   'NN',
#   'PREP',
#   'VFM',
#   'SYM',
#   'NEG',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'NLOC',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'CC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'NN',
#   'Unk',
#   'VAUX',
#   'INTF',
#   'RP',
#   'Unk',
#   'NNPC',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'QF',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NN',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'CC',
#   'Unk',
#   'NN',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'CC',
#   'Unk',
#   'NN',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'VNN',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'CC',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'NLOC',
#   'PRP',
#   'Unk',
#   'VFM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'JJ',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'INTF',
#   'NN',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'VNN',
#   'PREP',
#   'RB',
#   'RP',
#   'QFNUM',
#   'PRP',
#   'NN',
#   'NEG',
#   'Unk',
#   'CC',
#   'RB',
#   'Unk',
#   'RP',
#   'RB',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'NN',
#   'PREP',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'NN',
#   'VFM',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NN',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PREP',
#   'NVB',
#   'NEG',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'INTF',
#   'JJ',
#   'Unk',
#   'PREP',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'INTF',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'NN',
#   'Unk',
#   'RP',
#   'NEG',
#   'SYM',
#   'PRP',
#   'Unk',
#   'VNN',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'JVB',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'Unk',
#   'INTF',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'CC',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NN',
#   'PRP',
#   'Unk',
#   'Unk',
#   'RP',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'INTF',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'RP',
#   'NN',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'CC',
#   'PRP',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'NLOC',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'RB',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NVB',
#   'VFM',
#   'CC',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'RB',
#   'NN',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'RB',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'QF',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'JJ',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QF',
#   'RP',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'RB',
#   'RP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'NEG',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'QF',
#   'QW',
#   'PREP',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NVB',
#   'Unk',
#   'VFM',
#   'SYM',
#   'PRP',
#   'RP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'RB',
#   'NEG',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NN',
#   'PREP',
#   'QF',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NVB',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'NVB',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'CC',
#   'Unk',
#   'QFNUM',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'VJJ',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'VFM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NVB',
#   'VAUX',
#   'VAUX',
#   'CC',
#   'RB',
#   'QF',
#   'RP',
#   'NEG',
#   'VFM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VNN',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'QW',
#   'RP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'INTF',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'QW',
#   'NN',
#   'PREP',
#   'INTF',
#   'RB',
#   'VFM',
#   'VFM',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VNN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PREP',
#   'NN',
#   'VFM',
#   'CC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'SYM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'RB',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'INTF',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PRP',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'NEG',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'NN',
#   'VFM',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'NVB',
#   ...],
#  ['PRP',
#   'NN',
#   'RB',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VAUX',
#   'CC',
#   'JJ',
#   'NN',
#   'Unk',
#   'JVB',
#   'VNN',
#   'PREP',
#   'PREP',
#   'JVB',
#   'VAUX',
#   'SYM',
#   'NN',
#   'NVB',
#   'VFM',
#   'Unk',
#   'VFM',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'SYM',
#   'CC',
#   'QW',
#   'QF',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'NEG',
#   'Unk',
#   'RB',
#   'Unk',
#   'Unk',
#   'NN',
#   'RP',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NN',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RB',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'NN',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'INTF',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'NN',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'INTF',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'NNP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'NEG',
#   'Unk',
#   'CC',
#   'VFM',
#   'QW',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'NN',
#   'PREP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'QW',
#   'Unk',
#   'PREP',
#   'RP',
#   'PRP',
#   'RP',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'RB',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RB',
#   'Unk',
#   'JVB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'PRP',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'NN',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'JVB',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'SYM',
#   'Unk',
#   'RB',
#   'RP',
#   'INTF',
#   'JJ',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VNN',
#   'VFM',
#   'SYM',
#   'RB',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VNN',
#   'VFM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PRP',
#   'VFM',
#   'PRP',
#   'NEG',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'QF',
#   'RP',
#   'VFM',
#   'SYM',
#   'QW',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'VFM',
#   'CC',
#   'QW',
#   'Unk',
#   'PREP',
#   'Unk',
#   'SYM',
#   'PRP',
#   'RP',
#   'Unk',
#   'VFM',
#   'CC',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'NN',
#   'PREP',
#   'NN',
#   'PREP',
#   'NVB',
#   'VNN',
#   'PREP',
#   'NEG',
#   'Unk',
#   'CC',
#   'NN',
#   'RP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NVB',
#   'VNN',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'RB',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'VFM',
#   'VFM',
#   'RP',
#   'RB',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'SYM',
#   'Unk',
#   'NN',
#   'PREP',
#   'NN',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PREP',
#   'RB',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'NVB',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RB',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'QFNUM',
#   'RP',
#   'NN',
#   'Unk',
#   'Unk',
#   'CC',
#   'PRP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'RP',
#   'Unk',
#   'Unk',
#   'NVB',
#   'Unk',
#   'SYM',
#   'PRP',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'PRP',
#   'RP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'RP',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'VFM',
#   'SYM',
#   'QFNUM',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'PRP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'SYM',
#   'Unk',
#   'PRP',
#   'NN',
#   'INTF',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PRP',
#   'VNN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'NN',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'Unk',
#   'PREP',
#   'PRP',
#   'JJ',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'RB',
#   'QFNUM',
#   'RP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'JJ',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PUNC',
#   'RB',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RB',
#   'NVB',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'RP',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'NLOC',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'RB',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PRP',
#   'RP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'RP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'INTF',
#   'JVB',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NLOC',
#   'QF',
#   'RP',
#   'NN',
#   'Unk',
#   'NEG',
#   'VFM',
#   'SYM',
#   'PRP',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'CC',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'RP',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RP',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'QFNUM',
#   'NN',
#   'PRP',
#   'NVB',
#   'Unk',
#   'Unk',
#   'PRP',
#   'RP',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'QW',
#   'Unk',
#   'VFM',
#   'PRP',
#   'NLOC',
#   'PRP',
#   'NVB',
#   'JJ',
#   'RP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'RP',
#   'VAUX',
#   'PRP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'SYM',
#   'QF',
#   'Unk',
#   'CC',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'CC',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'VNN',
#   'NEG',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk'],
#  ['NN',
#   'NNP',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'INTF',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'CC',
#   'PRP',
#   'VAUX',
#   'Unk',
#   'NNC',
#   'Unk',
#   'PREP',
#   'SYM',
#   'QF',
#   'Unk',
#   'NN',
#   'Unk',
#   'PRP',
#   'Unk',
#   'NNC',
#   'NN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'NNC',
#   'Unk',
#   'PREP',
#   'PREP',
#   'NN',
#   'INTF',
#   'JJ',
#   'Unk',
#   'JVB',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'NN',
#   'PREP',
#   'Unk',
#   'NN',
#   'JJ',
#   'INTF',
#   'JJ',
#   'NN',
#   'RP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'CC',
#   'NN',
#   'NN',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'NN',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NVB',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'QW',
#   'RP',
#   'NNC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'PRP',
#   'QF',
#   'Unk',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QW',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'JJ',
#   'VNN',
#   'VFM',
#   'RB',
#   'Unk',
#   'RB',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VFM',
#   'SYM',
#   'QF',
#   'NN',
#   'PRP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'JVB',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'QF',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PUNC',
#   'QF',
#   'NN',
#   'RB',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'PREP',
#   'NNC',
#   'Unk',
#   'RP',
#   'QFNUM',
#   'INTF',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'NN',
#   'JJ',
#   'PREP',
#   'JJ',
#   'NN',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'NEG',
#   'PREP',
#   'PRP',
#   'Unk',
#   'NNPC',
#   'Unk',
#   'PREP',
#   'NN',
#   'VNN',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'PREP',
#   'RB',
#   'QFNUM',
#   'NN',
#   'RP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'RP',
#   'Unk',
#   'NNC',
#   'Unk',
#   'VFM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'INTF',
#   'PREP',
#   'NN',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'NNC',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'NVB',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'NN',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NNC',
#   'Unk',
#   'PREP',
#   'PREP',
#   'NN',
#   'PRP',
#   'QF',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'JVB',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RP',
#   'NNC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'QW',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'PREP',
#   'QF',
#   'JJ',
#   'Unk',
#   'NEG',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NN',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'NNC',
#   'Unk',
#   'VFM',
#   'RP',
#   'JJ',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QW',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'VNN',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PRP',
#   'RP',
#   'NN',
#   'VFM',
#   'PREP',
#   'RB',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NEG',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'RP',
#   'VFM',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'SYM',
#   'RB',
#   'JJ',
#   'Unk',
#   'PREP',
#   'JVB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'CC',
#   'RB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NNPC',
#   'NNC',
#   'Unk',
#   'VNN',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'NN',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'CC',
#   'PRP',
#   'RP',
#   'INTF',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'NNC',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'NEG',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'NEG',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VNN',
#   'VFM',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'VFM',
#   'SYM',
#   'PRP',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'PRP',
#   'RP',
#   'QF',
#   'VNN',
#   'VFM',
#   'PRP',
#   'PREP',
#   'JVB',
#   'VNN',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'QW',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NLOC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'JJ',
#   'Unk',
#   'PUNC',
#   'NN',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NN',
#   'VNN',
#   'VFM',
#   'SYM',
#   'RB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NVB',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NN',
#   'PREP',
#   'CC',
#   'PRP',
#   'RP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'RB',
#   'NEG',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'RB',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'NEG',
#   'VFM',
#   'PREP',
#   'PRP',
#   'PRP',
#   'NNC',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'RB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'RP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'RP',
#   'PRP',
#   'Unk',
#   'VNN',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'CC',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VFM',
#   'PREP',
#   'PRP',
#   'QW',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QW',
#   'Unk',
#   'SYM',
#   'RP',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VNN',
#   'RP',
#   'VFM',
#   'SYM',
#   'NEG',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'RB',
#   'Unk',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'QF',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'RB',
#   'Unk',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'PRP',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'NN',
#   'VNN',
#   'VFM',
#   'Unk',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'RP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'RB',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'INTF',
#   'VFM',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PREP',
#   'NN',
#   'PRP',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'RB',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'SYM',
#   'RB',
#   'PRP',
#   'NNC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VFM',
#   'SYM',
#   'QF',
#   'RP',
#   'NN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'PRP',
#   'RP',
#   'JJ',
#   'NN',
#   'VAUX',
#   'VAUX',
#   'PRP',
#   'NLOC',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'RP',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NN',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'NN',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PRP',
#   'VNN',
#   'PREP',
#   'PREP',
#   'PRP',
#   'RP',
#   'Unk',
#   'VNN',
#   'VAUX',
#   'PRP',
#   'PREP',
#   'JVB',
#   'VNN',
#   'VFM',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'PREP',
#   'Unk',
#   'NN',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'PREP',
#   'JJ',
#   'PREP',
#   'JVB',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'QF',
#   ...],
#  ['PRP',
#   'RB',
#   'QF',
#   'PRP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'PRP',
#   'INTF',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VFM',
#   'CC',
#   'Unk',
#   'PRP',
#   'QF',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QF',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'QF',
#   'PRP',
#   'NN',
#   'RP',
#   'VFM',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'Unk',
#   'RB',
#   'RP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'Unk',
#   'SYM',
#   'RB',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'RB',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'JJ',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NEG',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'RB',
#   'INTF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'RB',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'PREP',
#   'PRP',
#   'NN',
#   'NEG',
#   'Unk',
#   'SYM',
#   'NNPC',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'JJ',
#   'Unk',
#   'SYM',
#   'Unk',
#   'VNN',
#   'PREP',
#   'NN',
#   'Unk',
#   'PREP',
#   'PRP',
#   'NN',
#   'CC',
#   'Unk',
#   'NEG',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'QW',
#   'NN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NN',
#   'VFM',
#   'Unk',
#   'VFM',
#   'RP',
#   'Unk',
#   'JVB',
#   'RP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PRP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'PREP',
#   'RP',
#   'VFM',
#   'CC',
#   'PRP',
#   'NN',
#   'PRP',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VFM',
#   'SYM',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'NN',
#   'PREP',
#   'JVB',
#   'VNN',
#   'PREP',
#   'PRP',
#   'NEG',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'CC',
#   'PRP',
#   'Unk',
#   'RP',
#   'VFM',
#   'SYM',
#   'CC',
#   'QW',
#   'RP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'NN',
#   'NEG',
#   'VFM',
#   'SYM',
#   'Unk',
#   'RB',
#   'Unk',
#   'PREP',
#   'NNC',
#   'VAUX',
#   'QW',
#   'QFNUM',
#   'PREP',
#   'PRP',
#   'Unk',
#   'NEG',
#   'VFM',
#   'VAUX',
#   'SYM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'RB',
#   'JJ',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VFM',
#   'CC',
#   'NEG',
#   'SYM',
#   'RB',
#   'Unk',
#   'VNN',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'PREP',
#   'PRP',
#   'Unk',
#   'JJ',
#   'Unk',
#   'NN',
#   'Unk',
#   'VFM',
#   'SYM',
# ...
#   'Unk',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'PREP',
#   'PRP',
#   'VNN',
#   'PREP',
#   'NN',
#   'NEG',
#   'Unk',
#   'PRP',
#   'NN',
#   'CC',
#   'PRP',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'RP',
#   'Unk',
#   'PRP',
#   'RB',
#   'Unk',
#   'Unk',
#   'RP',
#   'NEG',
#   'VFM',
#   'Unk',
#   'Unk',
#   'NVB',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'CC',
#   'PRP',
#   'INTF',
#   'JJ',
#   'CC',
#   'INTF',
#   'NLOC',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'Unk',
#   'QF',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'NN',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'QFNUM',
#   'NN',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'PREP',
#   'Unk',
#   'NN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'CC',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NN',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'VAUX',
#   'CC',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'VAUX',
#   'PUNC',
#   'NN',
#   'PREP',
#   'PREP',
#   'JJ',
#   'Unk',
#   'QW',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'QW',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'NN',
#   'QFNUM',
#   'NN',
#   'PREP',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'QFNUM',
#   'PREP',
#   'PREP',
#   'INTF',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'Unk',
#   'RB',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'RP',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'NN',
#   'Unk',
#   'RP',
#   'VFM',
#   'Unk',
#   'NN',
#   'PREP',
#   'NVB',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RB',
#   'Unk',
#   'NN',
#   'PREP',
#   'NVB',
#   'VJJ',
#   'VAUX',
#   'RP',
#   'Unk',
#   'NVB',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'RB',
#   'Unk',
#   'NN',
#   'PREP',
#   'NN',
#   'NN',
#   'VJJ',
#   'VAUX',
#   'RP',
#   'Unk',
#   'PREP',
#   'NN',
#   'NN',
#   'RP',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'PREP',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'CC',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'RP',
#   'NN',
#   'PREP',
#   'Unk',
#   'NN',
#   'NEG',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NN',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'NN',
#   'PREP',
#   'NN',
#   'PUNC',
#   'Unk',
#   'CC',
#   'JJ',
#   'NN',
#   'PREP',
#   'NN',
#   'VNN',
#   'PREP',
#   'RP',
#   'NEG',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'NVB',
#   'PREP',
#   'PREP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'RP',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'NN',
#   'Unk'],
#  ['Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'NN',
#   'JVB',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'CC',
#   'NN',
#   'PRP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'RP',
#   'NN',
#   'Unk',
#   'VNN',
#   'PREP',
#   'NLOC',
#   'PRP',
#   'NN',
#   'VFM',
#   'Unk',
#   'CC',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'NN',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'PRP',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PREP',
#   'NN',
#   'RP',
#   'QFNUM',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PREP',
#   'VFM',
#   'VNN',
#   'PREP',
#   'NN',
#   'PREP',
#   'QFNUM',
#   'NVB',
#   'Unk',
#   'RP',
#   'RB',
#   'Unk',
#   'NN',
#   'QW',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'NN',
#   'VAUX',
#   'PRP',
#   'NN',
#   'NNP',
#   'PREP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VFM',
#   'NN',
#   'PREP',
#   'JJ',
#   'VNN',
#   'PREP',
#   'PREP',
#   'QW',
#   'Unk',
#   'PREP',
#   'QW',
#   'NN',
#   'VAUX',
#   'PUNC',
#   'RP',
#   'Unk',
#   'JJ',
#   'Unk',
#   'VNN',
#   'VFM',
#   'CC',
#   'QFNUM',
#   'NN',
#   'QW',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'CC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'VRB',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'RB',
#   'PRP',
#   'VNN',
#   'VFM',
#   'CC',
#   'Unk',
#   'QW',
#   'VAUX',
#   'CC',
#   'QW',
#   'NN',
#   'PREP',
#   'PRP',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'JJ',
#   'PRP',
#   'NN',
#   'PREP',
#   'NN',
#   'Unk',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'PUNC',
#   'QW',
#   'QFNUM',
#   'Unk',
#   'NN',
#   'VAUX',
#   'PUNC',
#   'QW',
#   'Unk',
#   'PREP',
#   'NN',
#   'QFNUM',
#   'NN',
#   'VAUX',
#   'PUNC',
#   'QW',
#   'NN',
#   'QFNUM',
#   'NN',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'NN',
#   'QFNUM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VJJ',
#   'VAUX',
#   'NN',
#   'CC',
#   'PRP',
#   'PREP',
#   'NN',
#   '',
#   'VNN',
#   'CC',
#   'PRP',
#   'VNN',
#   'PREP',
#   'QFNUM',
#   'NN',
#   'NN',
#   'VFM',
#   'Unk',
#   'RB',
#   'NN',
#   'VJJ',
#   'VAUX',
#   'QFNUM',
#   'JJ',
#   'NN',
#   'Unk',
#   'QFNUM',
#   'JJ',
#   'NN',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'NN',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'PRP',
#   'NN',
#   'Unk',
#   'PREP',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'CC',
#   'NNPC',
#   'PRP',
#   'NN',
#   'PREP',
#   'NN',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VJJ',
#   'Unk',
#   'QFNUM',
#   'JJ',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'CC',
#   'NN',
#   'PREP',
#   'JJ',
#   'VNN',
#   'PREP',
#   'NN',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'JVB',
#   'VFM',
#   'Unk',
#   'PRP',
#   'QFNUM',
#   'Unk',
#   'PREP',
#   'PREP',
#   'Unk',
#   'NNP',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'QFNUM',
#   'NN',
#   'CC',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'PUNC',
#   'PRP',
#   'NN',
#   'JJ',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'CC',
#   'PRP',
#   'NN',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'JJ',
#   'VNN',
#   'CC',
#   'VFM',
#   'VNN',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'NN',
#   'VJJ',
#   'VNN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'PREP',
#   'NN',
#   'PRP',
#   'NN',
#   'PREP',
#   'JJ',
#   'PREP',
#   'JJ',
#   'NN',
#   'PREP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'NNPC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'VAUX',
#   'CC',
#   'Unk',
#   'JJ',
#   'Unk',
#   'Unk',
#   'RB',
#   'Unk',
#   'JJ',
#   'VFM',
#   'PUNC',
#   'RB',
#   'Unk',
#   'Unk',
#   'NVB',
#   'VFM',
#   'PUNC',
#   'RB',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PUNC',
#   'RB',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'RB',
#   'JJ',
#   'NNP',
#   'PREP',
#   'NN',
#   'Unk',
#   'RB',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'NVB',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'JVB',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'JJ',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'NN',
#   'Unk',
#   'PREP',
#   'NVB',
#   'JVB',
#   'VFM',
#   'CC',
#   'Unk',
#   'Unk',
#   'JJ',
#   'VNN',
#   'PREP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'RP',
#   'NN',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'CC',
#   'NN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'NNP',
#   'PREP',
#   'QFNUM',
#   'JJ',
#   'NN',
#   'VFM',
#   'Unk',
#   'RP',
#   'Unk',
#   'JJ',
#   'VFM',
#   'Unk',
#   'CC',
#   'RB',
#   'Unk',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'CC',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NN',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'RP',
#   'NNP',
#   'NN',
#   'JJ',
#   'VFM',
#   'Unk'],
#  ['PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'Unk',
#   'QFNUM',
#   'NN',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'INTF',
#   'QFNUM',
#   'NN',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VNN',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'JJ',
#   'Unk',
#   'PRP',
#   'QF',
#   'CC',
#   'Unk',
#   'RP',
#   'Unk',
#   'VAUX',
#   'RB',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'CC',
#   'NLOC',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'RB',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'RB',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VAUX',
#   'CC',
#   'Unk',
#   'QW',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'PREP',
#   'VFM',
#   'Unk',
#   'PRP',
#   'Unk',
#   'RP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'PUNC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'JJ',
#   'NN',
#   'RP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'QFNUM',
#   'QFNUM',
#   'PREP',
#   'RP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'NLOC',
#   'NEG',
#   'Unk',
#   'QW',
#   'Unk',
#   'Unk',
#   'NEG',
#   'VFM',
#   'NN',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PUNC',
#   'NLOC',
#   'QF',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'NN',
#   'PRP',
#   'RP',
#   'Unk',
#   'Unk',
#   'NEG',
#   'Unk',
#   'PRP',
#   'VFM',
#   'PREP',
#   'Unk',
#   'RP',
#   'JJ',
#   'Unk',
#   'PRP',
#   'PREP',
#   'QFNUM',
#   'PREP',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'JVB',
#   'NEG',
#   'VFM',
#   'PUNC',
#   'PRP',
#   'RP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'NN',
#   'PRP',
#   'RP',
#   'Unk',
#   'NN',
#   'NEG',
#   'VFM',
#   'Unk',
#   'PUNC',
#   'PRP',
#   'VFM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'NN',
#   'RP',
#   'Unk',
#   'VJJ',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'PRP',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QFNUM',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'QFNUM',
#   'NN',
#   'JVB',
#   'NN',
#   'RP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'NN',
#   'Unk',
#   'RP',
#   'QF',
#   'NN',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RB',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'JVB',
#   'Unk',
#   'NN',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'PRP',
#   'JJ',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'NNP',
#   'Unk',
#   'NLOC',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'CC',
#   'PRP',
#   'NN',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'PUNC',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'QW',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PUNC',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'VNN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'NN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'VFM',
#   'NN',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'RP',
#   'Unk',
#   'NN',
#   'NEG',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VFM',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'CC',
#   'NN',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'NN',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'NN',
#   'PREP',
#   'Unk',
#   'NEG',
#   'Unk',
#   'Unk',
#   'SYM',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'Unk',
#   'NEG',
#   'VAUX',
#   'Unk',
#   'CC',
#   'PRP',
#   'PRP',
#   'QFNUM',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'QF',
#   'NN',
#   'VJJ',
#   'VAUX',
#   'Unk',
#   'QW',
#   'PREP',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'PRP',
#   'JJ',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'QW',
#   'PREP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'QW',
#   'PREP',
#   'INTF',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'RP',
#   'Unk',
#   'JJ',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'QW',
#   'PREP',
#   'PREP',
#   'Unk',
#   'Unk',
#   'JJ',
#   'NEG',
#   'VAUX',
#   'RP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'QW',
#   'PREP',
#   'PREP',
#   'PRP',
#   'JVB',
#   'NN',
#   'VAUX',
#   'RP',
#   'Unk',
#   'JJ',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'CC',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'CC',
#   'Unk',
#   'PREP',
#   'RP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'RP',
#   'QF',
#   'Unk',
#   'VFM',
#   'RP',
#   'PRP',
#   'Unk',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'PRP',
#   'NN',
#   'Unk',
#   'NEG',
#   'Unk',
#   'PRP',
#   'PRP',
#   'NN',
#   'NEG',
#   'Unk',
#   'INTF',
#   'PRP',
#   'NN',
#   'Unk',
#   'PRP',
#   'NN',
#   'PREP',
#   'JJ',
#   'NEG',
#   'VFM',
#   'Unk',
#   'PRP',
#   'NN',
#   'INTF',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'INTF',
#   'JVB',
#   'Unk',
#   'JJ',
#   'Unk',
#   'Unk',
#   'PREP',
#   'QW',
#   'PREP',
#   'NN',
#   'PREP',
#   'PRP',
#   'NNC',
#   'CC',
#   'NN',
#   'VNN',
#   'Unk',
#   'QW',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'QW',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'NNC',
#   'CC',
#   'NN',
#   'Unk',
#   'QW',
#   'PREP',
#   'Unk',
#   'NN',
#   'PREP',
#   'PRP',
#   'NN',
#   'CC',
#   'NN',
#   'Unk',
#   'PRP',
#   'Unk',
#   'JJ',
#   'VAUX',
#   'RP',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'JVB',
#   'Unk',
#   'PRP',
#   'RP',
#   'INTF',
#   'RP',
#   'Unk',
#   'NNPC',
#   'Unk',
#   'VAUX',
#   'PRP',
#   'NN',
#   'PREP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PRP',
#   'PREP',
#   'Unk',
#   'JJ',
#   'VFM',
#   'VAUX',
#   'PREP',
#   'QF',
#   'Unk',
#   'RP',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'VAUX',
#   'VFM',
#   'CC',
#   'PRP',
#   'PRP',
#   'RP',
#   'Unk',
#   'NEG',
#   'Unk',
#   'VFM',
#   'PREP',
#   'PRP',
#   'NEG',
#   'VAUX',
#   'Unk',
#   'QFNUM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'SYM',
#   'PRP',
#   'QF',
#   'NN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'NN',
#   'JVB',
#   'NEG',
#   'VFM',
#   'RB',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'SYM',
#   'Unk',
#   'SYM',
#   'VFM',
#   'PREP',
#   'PREP',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'NVB',
#   'VNN',
#   'PREP',
#   'RP',
#   'Unk',
#   'INTF',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'Unk',
#   'INTF',
#   'JJ',
#   'VAUX',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'PRP',
#   'QFNUM',
#   'Unk',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VNN',
#   'VFM',
#   'Unk',
#   'QW',
#   'Unk',
#   'PREP',
#   'NN',
#   'PREP',
#   'RB',
#   'PRP',
#   'PRP',
#   'NVB',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'VJJ',
#   'VAUX',
#   'CC',
#   'Unk',
#   'PRP',
#   'Unk',
#   'RP',
#   'Unk',
#   'Unk',
#   'VAUX',
#   'RP',
#   'Unk',
#   'NVB',
#   'RP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'CC',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'NN',
#   'Unk',
#   'Unk',
#   'Unk',
#   'PREP',
#   'Unk',
#   'Unk',
#   'JJ',
#   'PREP',
#   'JJ',
#   'NN',
#   'Unk',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'JJ',
#   'Unk',
#   'PREP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'RP',
#   'PRP',
#   'NN',
#   'PREP',
#   'NN',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VAUX',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'Unk',
#   'Unk',
#   'RP',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'RP',
#   'NVB',
#   'VNN',
#   'CC',
#   'Unk',
#   'NVB',
#   'VNN',
#   'PREP',
#   'JJ',
#   'PRP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'Unk',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'Unk',
#   'Unk',
#   'NN',
#   'PREP',
#   'Unk',
#   'PRP',
#   'NVB',
#   'VFM',
#   'Unk',
#   'VAUX',
#   'CC',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VAUX',
#   'Unk',
#   'JJ',
#   'VFM',
#   'Unk',
#   'Unk',
#   'PRP',
#   'Unk',
#   'PREP',
#   'CC',
#   'PRP',
#   'Unk',
#   'Unk',
#   'VFM',
#   'VFM',
#   'VAUX',
#   'VAUX',
#   'PRP',
#   'Unk',
#   'Unk',
#   'PRP',
#   'NN',
#   'Unk',
#   'NVB',
#   'VFM',
#   'VNN',
#   'PREP',
#   'PREP',
#   'RP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'Unk',
#   'PREP',
#   'PRP',
#   'NN',
#   'PREP',
#   'NN',
#   'PREP',
#   'Unk']]

# %%
string_representation=[]
for each in tagged_document:
    string_representation+=[" ".join(each)]

# %%
vectorizer = CountVectorizer(analyzer='word')
X=vectorizer.fit_transform(string_representation)
train_data_X=pd.DataFrame(data=X.toarray(),columns=vectorizer.get_feature_names())

# %%
pos=train_data_X

# %%
len(files)
# Out:
# 70

# %%
    train_data_X=[]
    start=chr(0x900)                    
    end=chr(0x97F)                      

    vectorizer=CountVectorizer(token_pattern="["+start+"-"+end+"]+",min_df = 0)

   

  

    document=[]
    length=[]
    hapax=[]
    word_count=[]
    no_of_english_words=[]                                                  # number of english words that an author uses
    avg_word_length=[]                                                      # length of document divided by number of words
    no_of_unique_words=[]                                                   # vocabulary richness
    freq_length_dist=[]
    for file in files:
        doc = codecs.open(file, "r", encoding='utf-16')
        doc = doc.read()
        words=doc.split(' ')
        freq_dist=FreqDist(words)
        no_of_hapax=len(freq_dist.hapaxes())
        hapax=hapax+[no_of_hapax]
        freq_of_different_words=[0 for i in range(15)]
        unique_words=set(words)
        no_of_unique_words=no_of_unique_words+[len(unique_words)]
        no_of_words=len(words)
        word_count = word_count + [no_of_words]
        avg_word_length=avg_word_length+[len(doc)/no_of_words]
        english_words=[]
        for each_word in words:
            if(len(each_word)>14):
                words.remove(each_word)
                continue;
            freq_of_different_words[len(each_word)]=freq_of_different_words[len(each_word)]+1
            if((len(each_word)>0) and (ord(each_word[0])<=126)):
                english_words=english_words+[each_word]
        freq_length_dist+=[freq_of_different_words]
        no_of_english_words=no_of_english_words+[len(english_words)]
        length=length+[len(doc)]
        document=document+[doc]

    #transforming data into feature vector
    X=vectorizer.fit_transform(document)
    train_data_X=pd.DataFrame(data=X.toarray(),columns=vectorizer.get_feature_names())

# %%
len(document)
# Out:
# 70

# %%
    sum=[]
    columns=[]
    for each in train_data_X.columns:
        sum_of_values=train_data_X[each].sum()
        sum=sum+[sum_of_values]
        columns=columns+[each]

    sum=pd.Series(data=sum,index=columns)

    cut_off=train_data_X.shape[0]

    function_words=sum[sum>(cut_off/2)]


    X=vectorizer.fit_transform(document)
    train_data_X=pd.DataFrame(data=X.toarray(),columns=vectorizer.get_feature_names())
    train_data_X=train_data_X[function_words.index]

#adding additional features: no of english words per document
    no_of_english_words=pd.DataFrame(no_of_english_words,columns=['no_of_english_words'])
    no_of_english_words=no_of_english_words.assign(avg_word_length=avg_word_length)
    no_of_english_words=no_of_english_words.assign(no_of_unique_words=no_of_unique_words)
    no_of_english_words=no_of_english_words.assign(hapax=hapax)
    freq_length_dist=pd.DataFrame(freq_length_dist)
    no_of_english_words=pd.concat([no_of_english_words,freq_length_dist],axis=1)
    no_of_english_words=no_of_english_words.div(length,axis=0)
    train_data_X=pd.concat([train_data_X,no_of_english_words],axis=1)



    

    pd.concat([pos,train_data_X],axis=1)
# Out:
#     cc  intf  jj  jvb  neg  nloc   nn  nnc  nnp  nnpc    ...            5  \
# 0   21    16  18    4   24     4   44    0    0     0    ...     0.031144
# 1   51    11  34    4   24     5   92    3    1     0    ...     0.019949
# 2   23    13  11    6   19     3   36    1    1     1    ...     0.023945
# 3   16     5  11    5    8     3   26    0    1     0    ...     0.019344
# 4   42    20  39   19   25     4   97   26    1     4    ...     0.023704
# 5   20     3   8    9   16     0   40    1    0     1    ...     0.029251
# 6   18     2   7    3    9     2   26    1    0     0    ...     0.033166
# 7   22     4   7    4   19     2   26    1    1     3    ...     0.024510
# 8    7     3   1    3    3     1   20    1    0     0    ...     0.025489
# 9   38    24  23   27   36     8   94    2    2     3    ...     0.022006
# 10  23     5  17    7   14     0   14    3    1     1    ...     0.026912
# 11  26     9  27    5   18     7   47    1    3     1    ...     0.022591
# 12  25     9  16    3   20     6   36    0    0     0    ...     0.028766
# 13  35    13  30    5   32     0   78    3    0     1    ...     0.028068
# 14  35     6  13    3   12    11   28    1    0     0    ...     0.025578
# 15  27    11   3    4   10     8   30    2    2     0    ...     0.026469
# 16  19     3   7    0    7     3   14    2    1     0    ...     0.029251
# 17  13     4   4    4    6     6   16    1    0     3    ...     0.026578
# 18  55     6  15    5   26    18   72    3    1     3    ...     0.024514
# 19  24     6   6    4   10    13   48    0    1     0    ...     0.020323
# 20  32     6   7    3   13     3   28    1    1     0    ...     0.026144
# 21  30     7   5    6   12     6   58    1    1     0    ...     0.021251
# 22  25     2   4    0   21     5   12    1    2     0    ...     0.026300
# 23  11     1   0    0   15     0   14    5    0     1    ...     0.031303
# 24  76    13  17    1   23     7   69    0    0     2    ...     0.024896
# 25  28     0   3    0   11     5   24    1    1     1    ...     0.025298
# 26  46     7  11    6   14     7   86    3    4     2    ...     0.023012
# 27  66     9  20    3   42    11   68    6    3    13    ...     0.024514
# 28  44     8  17    5    3     4   56   20    1     0    ...     0.019017
# 29  34     8  23    7    8     3   55    4    3     2    ...     0.018904
# ..  ..   ...  ..  ...  ...   ...  ...  ...  ...   ...    ...          ...
# 40  45     4   8    4    8     7   59    1    1     0    ...     0.024383
# 41  48     5   9    5    8     2   53    6    1     1    ...     0.022758
# 42  52    10   9    5   20     7   87   14    0    16    ...     0.025759
# 43  69    10  55    9   11     4  143    1    0     1    ...     0.019641
# 44  35    15  17    5   17    13   37    2    1     1    ...     0.018191
# 45  24    12  16    1   16     6   40    0    0     4    ...     0.023987
# 46  41     8  26   10    2     3   81    3    0     2    ...     0.021332
# 47  53     7  27    2   14    10   70    3    5     2    ...     0.027676
# 48  45     3   9    7   24     9   45    4    4     9    ...     0.018562
# 49  19    10   2    1    2     1   31    1    0     2    ...     0.023713
# 50  68    16  59   15   16     8  133    2    0     3    ...     0.023983
# 51  32     9  15    3    9     2   37    5    0     1    ...     0.027513
# 52  69    16  54    4   30     9  100    1    1     0    ...     0.024178
# 53  63    11  24    5   26     7  105    0    2     2    ...     0.022391
# 54   7     2   1    4    1     1   25    1    0     0    ...     0.037187
# 55  16     4  11    1    7     4   41    1    3     0    ...     0.030163
# 56  45    15  27    7   16     1   75    1    0     3    ...     0.017509
# 57  47    12  25    9   13     6   91    4    2     1    ...     0.021978
# 58  51    12  24    3   29     9   73    1    0     3    ...     0.027697
# 59  32     2  17    2   14     2   45    0    0     1    ...     0.024053
# 60  15     1  11    3    7     2   23    0    1     0    ...     0.023047
# 61  74    13  27    4   20     5   93    2    3     0    ...     0.029819
# 62  18     3   4    3   11     1   25    0    0     1    ...     0.028292
# 63  15     4   9    3    3     2   17    1    0     0    ...     0.028918
# 64  76    13  27    4   20     5   93    2    3     0    ...     0.029654
# 65  16     1   3    0    3     0   26    0    0     0    ...     0.015072
# 66  67     5  30    5    9     4   57    3    0     1    ...     0.023112
# 67  20     6   9    5    9     1   70    1    0     0    ...     0.021093
# 68  24     0  26    4    1     1   58    0    5     2    ...     0.019687
# 69  21     9  18    7   15     4   54    2    1     1    ...     0.022768
#
#            6         7         8         9        10        11        12  \
# 0   0.008686  0.004025  0.001483  0.002331  0.004237  0.001907  0.000847
# 1   0.008132  0.007751  0.002795  0.002287  0.005083  0.002414  0.000762
# 2   0.013935  0.004514  0.001963  0.002552  0.002552  0.000393  0.000196
# 3   0.008964  0.004482  0.002123  0.001180  0.010852  0.000236  0.001180
# 4   0.012511  0.006020  0.002446  0.002540  0.003010  0.001223  0.000847
# 5   0.011208  0.004374  0.000820  0.001093  0.000547  0.001093  0.000547
# 6   0.011558  0.010553  0.004020  0.001508  0.000503  0.000503  0.000503
# 7   0.008272  0.006740  0.003064  0.000306  0.001225  0.000613  0.000306
# 8   0.007706  0.005335  0.001186  0.001186  0.000593  0.000000  0.000000
# 9   0.011117  0.008711  0.003209  0.001605  0.000917  0.000688  0.000344
# 10  0.013904  0.006728  0.003588  0.005158  0.001794  0.000449  0.000224
# 11  0.012024  0.005830  0.002186  0.001640  0.002004  0.001275  0.001093
# 12  0.009336  0.005299  0.003280  0.000757  0.002019  0.000757  0.000757
# 13  0.013075  0.003835  0.003312  0.001918  0.001743  0.001046  0.000697
# 14  0.016379  0.005834  0.003365  0.003590  0.001346  0.000224  0.000897
# 15  0.010652  0.008715  0.003551  0.003228  0.000646  0.001614  0.000646
# 16  0.015369  0.009916  0.004462  0.004958  0.002479  0.000496  0.000992
# 17  0.013843  0.006645  0.004430  0.003322  0.002215  0.000554  0.001107
# 18  0.010294  0.008490  0.004882  0.003078  0.001486  0.001061  0.000212
# 19  0.013226  0.005484  0.004839  0.005806  0.000645  0.001935  0.001290
# 20  0.012830  0.007262  0.003389  0.005084  0.001937  0.000726  0.000726
# 21  0.013577  0.004723  0.000295  0.002656  0.001476  0.002066  0.001771
# 22  0.016736  0.008667  0.003586  0.002391  0.002391  0.000598  0.000598
# 23  0.014229  0.007968  0.003984  0.002277  0.000569  0.001707  0.002277
# 24  0.013085  0.009958  0.006832  0.003821  0.002547  0.001505  0.001505
# 25  0.015179  0.007440  0.008929  0.002381  0.002381  0.001190  0.001190
# 26  0.010769  0.006491  0.003688  0.003688  0.001770  0.001623  0.003098
# 27  0.016378  0.005600  0.005389  0.004121  0.001691  0.002008  0.001796
# 28  0.016376  0.011886  0.004226  0.003698  0.001321  0.000528  0.000264
# 29  0.013233  0.010802  0.004051  0.003241  0.000810  0.004051  0.000810
# ..       ...       ...       ...       ...       ...       ...       ...
# 40  0.017377  0.007007  0.003643  0.002242  0.001401  0.000561  0.000280
# 41  0.016867  0.006961  0.009906  0.004284  0.001339  0.000535  0.000268
# 42  0.014697  0.007585  0.003793  0.001896  0.002212  0.001738  0.001106
# 43  0.012447  0.008565  0.003768  0.003426  0.003997  0.000914  0.000914
# 44  0.010964  0.004735  0.002741  0.001994  0.001744  0.000997  0.000748
# 45  0.009877  0.008869  0.002016  0.002419  0.001411  0.001209  0.000605
# 46  0.013790  0.009696  0.004094  0.006895  0.001508  0.000646  0.000646
# 47  0.010096  0.008355  0.003481  0.004003  0.001044  0.001393  0.000522
# 48  0.009065  0.005396  0.006691  0.003453  0.000863  0.000216  0.001079
# 49  0.017154  0.007568  0.006054  0.005550  0.002523  0.000000  0.000505
# 50  0.010493  0.008244  0.003854  0.003105  0.002891  0.001071  0.001713
# 51  0.012698  0.005026  0.001058  0.003439  0.000265  0.000529  0.000529
# 52  0.010394  0.009264  0.004519  0.003502  0.002373  0.002486  0.002147
# 53  0.008306  0.007102  0.002889  0.003250  0.002408  0.001083  0.001324
# 54  0.006467  0.003234  0.008892  0.000808  0.000808  0.001617  0.000000
# 55  0.011311  0.007960  0.003770  0.003351  0.002095  0.002095  0.000838
# 56  0.019833  0.006043  0.006043  0.002014  0.001549  0.000930  0.000310
# 57  0.010574  0.009538  0.002488  0.001244  0.001037  0.001451  0.000207
# 58  0.009181  0.007651  0.005203  0.002601  0.001683  0.001377  0.000765
# 59  0.011193  0.004763  0.000476  0.001905  0.001429  0.000476  0.001667
# 60  0.016219  0.010243  0.001707  0.005122  0.002134  0.001280  0.001280
# 61  0.012405  0.005844  0.002147  0.001551  0.000835  0.000954  0.001789
# 62  0.011317  0.005144  0.000000  0.001029  0.000514  0.000514  0.001029
# 63  0.010989  0.008676  0.002313  0.001157  0.001735  0.001157  0.000578
# 64  0.012474  0.005766  0.002118  0.001530  0.001059  0.000941  0.001765
# 65  0.017693  0.009174  0.005242  0.002621  0.005898  0.001311  0.000655
# 66  0.012689  0.007402  0.007402  0.002719  0.003021  0.001511  0.001511
# 67  0.014869  0.012448  0.001729  0.001729  0.001383  0.002075  0.000692
# 68  0.010044  0.006428  0.008437  0.002009  0.001205  0.000804  0.000402
# 69  0.012173  0.007665  0.005185  0.001578  0.003381  0.002254  0.000902
#
#           13        14
# 0   0.000424  0.000847
# 1   0.000000  0.000635
# 2   0.000393  0.000000
# 3   0.000000  0.000000
# 4   0.000564  0.000282
# 5   0.000547  0.000000
# 6   0.000000  0.000000
# 7   0.000613  0.000000
# 8   0.001186  0.000000
# 9   0.000229  0.000573
# 10  0.000224  0.000000
# 11  0.000547  0.000182
# 12  0.000000  0.000000
# 13  0.000349  0.000174
# 14  0.000673  0.000897
# 15  0.000968  0.000646
# 16  0.000496  0.000000
# 17  0.000000  0.000554
# 18  0.000318  0.000106
# 19  0.000000  0.000000
# 20  0.000968  0.000484
# 21  0.000590  0.000295
# 22  0.000299  0.000000
# 23  0.000000  0.000000
# 24  0.000463  0.000347
# 25  0.001190  0.000000
# 26  0.000295  0.000443
# 27  0.001162  0.000423
# 28  0.000264  0.000000
# 29  0.000540  0.000000
# ..       ...       ...
# 40  0.000000  0.000000
# 41  0.000268  0.000268
# 42  0.001422  0.000474
# 43  0.000799  0.000799
# 44  0.000249  0.000000
# 45  0.000000  0.000403
# 46  0.001077  0.000000
# 47  0.001393  0.000348
# 48  0.000432  0.000000
# 49  0.000000  0.000000
# 50  0.000107  0.000428
# 51  0.000529  0.000529
# 52  0.000791  0.000339
# 53  0.000843  0.000361
# 54  0.000808  0.000000
# 55  0.000419  0.000000
# 56  0.001549  0.000775
# 57  0.001244  0.000415
# 58  0.001377  0.000459
# 59  0.001191  0.000238
# 60  0.001280  0.000427
# 61  0.000477  0.000239
# 62  0.000000  0.001029
# 63  0.000578  0.001157
# 64  0.000471  0.000235
# 65  0.000000  0.000000
# 66  0.000906  0.000302
# 67  0.000346  0.000692
# 68  0.000000  0.000402
# 69  0.000902  0.000902
#
# [70 rows x 301 columns]

# %%
len(train_data_X)
# Out:
# 70

# %%
x,y=train_data_X.shape
#term frequency normalization
train_data_X=train_data_X.div(length,axis=0)

#calculating idf for each column
import math as math
l=[]
for each in train_data_X.columns:
    document=0
    for value in train_data_X.loc[:,each]:
        if(value!=0):
            document=document+1
    data=math.log(x/document)
    l=l+[data]

#tf idf
train_data_X=train_data_X.mul(l,axis=1)

# %%
Y=[]
for author in authors:
    newpath=path+author+'/'
    x=os.listdir(newpath)
    for every_file in x:
        Y=Y+[author]

# %%
len(train_data_X)
# Out:
# 70

# %%
le=preprocessing.LabelEncoder()
train_data_Y=le.fit_transform(Y)

# %%
model=svm.SVC()

# %%
train_data_X=(train_data_X-train_data_X.min())/(train_data_X.max()-train_data_X.min())    #normalisation for learning algo
columns=train_data_X.columns[train_data_X.isnull().any()]
train_data_X=train_data_X.drop(columns,axis=1)

# %%
parameters = [{'kernel': ['rbf'],
                   'gamma': [1e-4, 1e-3, 0.01, 0.1, 0.2, 0.5],
                    'C': [1, 10, 100, 1000]},
                  {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

# %%
from sklearn.naive_bayes import  MultinomialNB

# %%
clf=GridSearchCV(model,param_grid=parameters,cv=10)

# %%
clf=MultinomialNB()

# %%
clf=cross_val_score(clf,train_data_X,train_data_Y,cv=10)

# %%
clf.mean()
# Out:
# 0.97
